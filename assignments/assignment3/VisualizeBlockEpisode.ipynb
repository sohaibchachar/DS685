# %%
# Out:
# ✅ Loaded 74530 episode path mappings

# %%
# Out:
# 📋 Selected episode ID: AUTOLab+0d4edc83+2023-10-27-20h-25m-34s
# 📋 Total episodes available: 172
# 📋 Current index: 0

# %%
# Out:
# 📦 Loading DROID dataset (droid)...
# 2025-11-03 19:06:31.878691: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-03 19:06:31.888341: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-03 19:06:32.297067: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# Out:
# 🔍 Searching for episode: AUTOLab+0d4edc83+2023-10-27-20h-25m-34s
# ...
# Searching episodes:   0%|          | 8/95658 [04:34<682:40:34, 25.69s/it]  2025-11-03 19:12:26.901426: E external/local_xla/xla/tsl/platform/cloud/curl_http_request.cc:611] The transmission  of request 0x77679c805370 (URI: https://storage.googleapis.com/gresearch/robotics%2Fdroid%2F1.0.1%2Fdroid_101-train.tfrecord-00036-of-02048) has been stuck at 59866272 of 67108864 bytes for 18446744073709551615 seconds and will be aborted. CURL timing information: lookup time: 0.003478 (No error), connect time: 0.0961 (No error), pre-transfer time: 0.21309 (No error), start-transfer time: 0.441597 (No error)
# ...
